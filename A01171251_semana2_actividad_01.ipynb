# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana 02**
# ###**Introducción al procesamiento de texto.**

# %% [markdown]
# En esta actividad deberás utilizar los datos del siguiente archivo que se encuentra en Canvas:
#
# MNA_NLP_semana_02_Actividad_datos.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open('MNA_NLP_semana_02_Actividad_datos.txt',        # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comentario por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[0:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\n',
#  'Crust is not good.\n',
#  'Not tasty and the texture was just nasty.\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\n',
#  'The selection on the menu was great and so were the prices.\n',
#  'Now I am getting angry and I want my damn pho.\n',
#  "Honeslty it didn't taste THAT fresh.)\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\n',
#  'The fries were great too.\n',
#  'A great touch.\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n' que se encuentran al final de cada comentario.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %%
docs = [re.sub(r'\n+', '', comment) for comment in docs]
docs[:10]
# Out:
# ['Wow... Loved this place.',
#  'Crust is not good.',
#  'Not tasty and the texture was just nasty.',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#  'The selection on the menu was great and so were the prices.',
#  'Now I am getting angry and I want my damn pho.',
#  "Honeslty it didn't taste THAT fresh.)",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.',
#  'The fries were great too.',
#  'A great touch.']

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %%
coincidencias = []
count = 0
for comment in docs:
    matches=re.findall(r'(\w+)(!{2,})',comment)
    if matches:
        count = count+1
        coincidencias.extend(matches)
for word, signs in coincidencias:
    print(f'{word},{signs}')
print (f"Total de resultados: {count}")
# Out:
# Firehouse,!!!!!
# APPETIZERS,!!!
# amazing,!!!
# buffet,!!!
# good,!!
# it,!!!!
# DELICIOUS,!!
# amazing,!!
# shawarrrrrrma,!!!!!!
# yucky,!!!
# steak,!!!!!
# delicious,!!!
# far,!!
# biscuits,!!!
# dry,!!
# disappointing,!!!
# awesome,!!
# Up,!!
# FLY,!!!!!!!!
# here,!!!
# great,!!!!!!!!!!!!!!
# packed,!!
# otherwise,!!
# amazing,!!!!!!!!!!!!!!!!!!!
# style,!!
# disappointed,!!
# Total de resultados: 26

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra.
#
# Indica cuántas palabras encontraste.

# %%
coincidencias = []
for comment in docs:
    matches=re.findall(r'\b[A-Z]{2,}\b',comment)
    if matches:
        coincidencias.extend(matches)
coincidencias = list(set(coincidencias))
for word in coincidencias:
    print(f'{word}')

print (f"Total de resultados: {len(coincidencias)}")
# Out:
# DELICIOUS
# NOW
# RI
# BEST
# AND
# ALL
# AZ
# TOTAL
# AYCE
# EVER
# UNREAL
# CONCLUSION
# AN
# HAVE
# MGM
# APPETIZERS
# BITCHES
# MANAGEMENT
# FREEZING
# OK
# FANTASTIC
# HANDS
# BARGAIN
# GC
# GREAT
# OVERPRICED
# BACK
# TV
# BBQ
# REAL
# REALLY
# BETTER
# LEGIT
# IT
# FORWARD
# OWNERS
# STALE
# SHOULD
# BARE
# WILL
# MUST
# WASTE
# THE
# PEOPLE
# WAY
# NASTY
# IN
# THIS
# OMG
# THAT
# WORST
# FLAVOR
# SCREAMS
# NONE
# EXPERIENCE
# NYC
# VERY
# TOLD
# AVOID
# RUDE
# NO
# FLY
# INCONSIDERATE
# NEVER
# PERFECT
# ESTABLISHMENT
# TIME
# NOT
# FS
# GO
# MANY
# HAPPENED
# WEAK
# WHAT
# OF
# LOVED
# STEP
# BLAND
# HAD
# AGAIN
# HOUR
# Total de resultados: 81

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %%
coincidencias = [comment for comment in docs if (letras := re.sub(r'[^A-Za-z]', '', comment)) and letras.isupper()]

# Imprimimos los comentarios en mayúsculas
for comentario in coincidencias:
    print(comentario)

# Imprimimos la cantidad de resultados encontrados
print(f"Total de comentarios encontrados: {len(coincidencias)}")
# Out:
# DELICIOUS!!
# RUDE & INCONSIDERATE MANAGEMENT.
# WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEOPLE WHAT HAD HAPPENED.
# TOTAL WASTE OF TIME.
# AVOID THIS ESTABLISHMENT!
# Total de comentarios encontrados: 5

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %%
# Buscamos palabras que tengan acentos
palabras_con_acento = []

for comment in docs:
    matches = re.findall(r'\b\w*[áéíóúÁÉÍÓÚñÑ]\w*\b', comment)
    if matches:
        palabras_con_acento.extend(matches)

# Imprimimos las palabras encontradas
for palabra in palabras_con_acento:
    print(palabra)

# Imprimimos cuántas encontramos
print(f"Total de palabras encontradas: {len(palabras_con_acento)}")
# Out:
# fiancé
# Café
# puréed
# Total de palabras encontradas: 3

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %%
palabras_con_dinero = []

# Buscamos cantidades monetarias que inicien con $, incluyendo comas para miles y decimales.
# El patrón busca:
# - Un símbolo de dólar literal (\$)
# - De 1 a 3 dígitos (\d{1,3})
# - Cero o más repeticiones de un grupo de coma seguido de tres dígitos ((?:,\d{3})*)
# - Opcionalmente, un punto seguido de uno o dos dígitos decimales ((?:\.\d{1,2})?)

for comment in docs:
    matches = re.findall(r'\$\d{1,3}(?:,\d{3})*(?:\.\d{1,2})?', comment)
    if matches:
        palabras_con_dinero.extend(matches)

# Imprimimos las palabras encontradas
for palabra in palabras_con_dinero:
    print(palabra)

# Imprimimos cuántas encontramos
print(f"Total de palabras encontradas: {len(palabras_con_dinero)}")
# Out:
# $20
# $4.00
# $17
# $3
# $35
# $7.85
# $12
# $11.99
# Total de palabras encontradas: 8

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love", sin importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra.
#
# Indica cuántos resultados obtuviste.

# %%
love = []

for comment in docs:
    matches = re.findall(r'\b\w*love\w*\b', comment, re.IGNORECASE)
    if matches:
        love.extend(matches)

# Imprimimos las palabras encontradas
for palabra in love:
    print(palabra)

# Imprimimos cuántas encontramos
print(f"Total de palabras encontradas: {len(love)}")
# Out:
# Loved
# loved
# Loved
# love
# loves
# LOVED
# lovers
# love
# lovers
# Love
# loved
# loved
# love
# love
# love
# loved
# love
# loved
# Love
# LOVED
# love
# lovely
# love
# lovely
# love
# lover
# loved
# love
# love
# love
# love
# gloves
# love
# love
# love
# love
# Total de palabras encontradas: 36

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras, variantes de "so" y "good", que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Indica cuántas encontraste.

# %%
sogood = []

for comment in docs:
    matches = re.findall(r'\b(?:so{2,}|go{3,}d{1,})\b', comment, re.IGNORECASE)
    if matches:
        sogood.extend(matches)

# Imprimimos las palabras encontradas
for palabra in sogood:
    print(palabra)

# Imprimimos cuántas encontramos
print(f"Total de palabras encontradas: {len(sogood)}")
# Out:
# Sooooo
# soooo
# gooodd
# soooooo
# soooo
# Total de palabras encontradas: 5

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 10 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %%
long10 = []

for comment in docs:
    matches = re.findall(r'\b\w{11,}\b', comment, re.IGNORECASE)
    if matches:
        long10.extend(matches)

# Imprimimos las palabras encontradas
for palabra in long10:
    print(palabra)
# Out:
# recommendation
# recommended
# overwhelmed
# inexpensive
# establishment
# imaginative
# opportunity
# experiencing
# underwhelming
# relationship
# unsatisfying
# disappointing
# outrageously
# disappointing
# expectations
# restaurants
# suggestions
# disappointed
# considering
# Unfortunately
# immediately
# ingredients
# accommodations
# maintaining
# Interesting
# disrespected
# accordingly
# unbelievable
# cheeseburger
# descriptions
# inexpensive
# disappointed
# Veggitarian
# outstanding
# recommendation
# disappointed
# disappointed
# neighborhood
# disappointed
# corporation
# considering
# exceptional
# shawarrrrrrma
# disappointed
# vinaigrette
# immediately
# unbelievably
# replenished
# disappointed
# enthusiastic
# Outstanding
# comfortable
# interesting
# INCONSIDERATE
# considering
# transcendant
# disappointment
# disappointed
# disappointed
# overwhelmed
# professional
# Furthermore
# combination
# connoisseur
# profiterole
# outstanding
# acknowledged
# ...

# %%
# Imprimimos cuántas encontramos
print(f"Total de palabras encontradas: {len(long10)}")
# Out:
# Total de palabras encontradas: 141

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string.
#
# Indica la cantidad de resultados obtenidos.

# %%
maymin = []

for comment in docs:
    matches = re.findall(r'(?<=\s)[A-Z][a-zA-Z]*[a-z]\b', comment)
    if matches:
        maymin.extend(matches)

# Imprimimos las palabras encontradas
for palabra in maymin:
    print(palabra)
# Out:
# Loved
# May
# Rick
# Steve
# Cape
# Cod
# Vegas
# Burrittos
# Blah
# The
# They
# Mexican
# Luke
# Our
# Hiro
# Firehouse
# Greek
# Greek
# Heart
# Attack
# Grill
# Vegas
# Dos
# Gringos
# Jeff
# Really
# Excalibur
# Very
# Bad
# Customer
# Service
# Vegas
# Rice
# Company
# Pho
# Hard
# Rock
# Casino
# Buffet
# Tigerlilly
# Yama
# Thai
# Indian
# Not
# Vegas
# Lox
# Subway
# Subway
# Vegas
# Vegas
# Mandalay
# Bay
# Great
# Voodoo
# Phoenix
# Vegas
# Khao
# Soi
# Lemon
# Joey
# Valley
# Phoenix
# Magazine
# Pho
# Fridays
# Tasty
# Jamaican
# Bisque
# Bussell
# Sprouts
# Risotto
# Filet
# Otto
# Yeah
# Honestly
# Not
# Also
# Vegas
# Greek
# Vegas
# Veggitarian
# Madison
# Ironman
# Jenni
# Pho
# Bachi
# Burger
# Pizza
# Salads
# They
# Yelpers
# Bachi
# Service
# English
# Pizza
# Hut
# Seat
# Standard
# Thai
# Tucson
# Vegas
# Chipotle
# Gordon
# Ramsey
# Steak
# Vegas
# Outstanding
# Best
# Food
# Lobster
# Bisque
# Vegas
# Eggplant
# Green
# Bean
# Halibut
# Vegas
# Vegas
# ...

# %%
print(f"Total de palabras encontradas: {len(maymin)}")
# Out:
# Total de palabras encontradas: 266

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían.
#
# Indica la cantidad de resultados obtenidos.

# %%
guion = []

for comment in docs:
    matches = re.findall(r'\b\w+-\w+\b', comment)
    if matches:
        guion.extend(matches)

# Imprimimos las palabras encontradas
for palabra in guion:
    print(palabra)
print(f"Total de palabras encontradas: {len(guion)}")
# Out:
# flat-lined
# hands-down
# must-stop
# sub-par
# Service-check
# in-house
# been-stepped
# in-and
# tracked-everywhere
# multi-grain
# to-go
# non-customer
# High-quality
# sit-down
# over-whelm
# low-key
# non-fancy
# golden-crispy
# over-priced
# over-hip
# under-services
# Total de palabras encontradas: 21

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan en "ing" o "ed".
#
# Indica la cantidad de palabras que encontraste de cada una.

# %%
inged = []

for comment in docs:
    matches = re.findall(r'\b\w+(?:ing|ed)\b', comment,re.IGNORECASE)
    if matches:
        inged.extend(matches)

# Imprimimos las palabras encontradas
for palabra in inged:
    print(palabra)
print(f"Total de palabras encontradas: {len(inged)}")
# Out:
# Loved
# Stopped
# during
# loved
# getting
# being
# ended
# being
# overpriced
# tried
# disgusted
# shocked
# recommended
# amazing
# performed
# red
# asked
# running
# overwhelmed
# redeeming
# grossed
# melted
# getting
# provided
# thing
# cooked
# dressing
# refreshing
# ordered
# running
# realized
# Loved
# lined
# cooked
# ripped
# ripped
# petrified
# amazing
# included
# expected
# nothing
# appalling
# seasoned
# cheated
# wasting
# eating
# going
# Coming
# experiencing
# underwhelming
# walked
# smelled
# eating
# raving
# tailored
# spring
# unsatisfying
# amazing
# Everything
# disappointing
# dining
# flirting
# arrived
# roasted
# added
# thing
# coming
# LOVED
# cooked
# playing
# passed
# ordering
# arriving
# liked
# disappointing
# managed
# served
# preparing
# loving
# liking
# reviewing
# venturing
# overpriced
# including
# during
# checked
# disappointed
# red
# decorated
# changing
# going
# considering
# served
# coming
# watched
# greeted
# seated
# ...

# %%
print(f"Total de palabras encontradas: {len(inged)}")
# Out:
# Total de palabras encontradas: 619

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
cleaned_docs = []

for comment in docs:
    # 1. Eliminar todo lo que no sean letras o espacios
    comment = re.sub(r'[^a-zA-Z\s]', '', comment)
    # 2. Convertir todo a minúsculas
    comment = comment.lower()
    # 3. Eliminar espacios adicionales
    comment = re.sub(r'\s+', ' ', comment).strip()
    # 4. Agregar al nuevo corpus limpio
    cleaned_docs.append(comment)

# Imprimimos los primeros 10 comentarios limpios
for i in range(10):
    print(f"{i+1}: {cleaned_docs[i]}")
# Out:
# 1: wow loved this place
# 2: crust is not good
# 3: not tasty and the texture was just nasty
# 4: stopped by during the late may bank holiday off rick steve recommendation and loved it
# 5: the selection on the menu was great and so were the prices
# 6: now i am getting angry and i want my damn pho
# 7: honeslty it didnt taste that fresh
# 8: the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer
# 9: the fries were great too
# 10: a great touch

# %% [markdown]
# *   **Pregunta 14.**
#
# Con el resultado de la limpieza obtenido en la pregunta anterior, realiza ahora un proceso de tokenización por palabras del corpus.
#
# Es decir, al final de este proceso de tokenización, debes tener como resultado una lista de listas, donde cada comentario estará tokenizado por palabras.
#
# Al terminar calcula el total de tokens obtenido en todo el corpus.

# %%
docs_tokens = []
for comment in cleaned_docs:
    tokens = comment.split()  # Divide en palabras
    docs_tokens.append(tokens)

# Mostrar los primeros 10 comentarios tokenizados
print("\nPrimeros 10 comentarios TOKENIZADOS:")
for tokens in docs_tokens[:10]:
    print(tokens)

# Paso 3: Calcular el total de tokens
total_tokens = sum(len(tokens) for tokens in docs_tokens)
print(f"\nTotal de tokens en todo el corpus: {total_tokens}")
# Out:
# Primeros 10 comentarios TOKENIZADOS:
# ['wow', 'loved', 'this', 'place']
# ['crust', 'is', 'not', 'good']
# ['not', 'tasty', 'and', 'the', 'texture', 'was', 'just', 'nasty']
# ['stopped', 'by', 'during', 'the', 'late', 'may', 'bank', 'holiday', 'off', 'rick', 'steve', 'recommendation', 'and', 'loved', 'it']
# ['the', 'selection', 'on', 'the', 'menu', 'was', 'great', 'and', 'so', 'were', 'the', 'prices']
# ['now', 'i', 'am', 'getting', 'angry', 'and', 'i', 'want', 'my', 'damn', 'pho']
# ['honeslty', 'it', 'didnt', 'taste', 'that', 'fresh']
# ['the', 'potatoes', 'were', 'like', 'rubber', 'and', 'you', 'could', 'tell', 'they', 'had', 'been', 'made', 'up', 'ahead', 'of', 'time', 'being', 'kept', 'under', 'a', 'warmer']
# ['the', 'fries', 'were', 'great', 'too']
# ['a', 'great', 'touch']
#
# Total de tokens en todo el corpus: 10777

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras "stopwords", las cuales deberás eliminar de todo el corpus.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera, que tienen frecuencias de aparición muy altas en cualquier documento, pero que no brindan mucho significado en cuanto al significado de un enunciado.
#
# Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior.
#
# Obtener cuántos tokens/palabras quedan finalmente en todo el corpus.
#
# Obtener cuántos de estos tokens/palabras son diferentes, es decir, cuántos tokens únicos tendrá lo que llamaremos más adelante nuestro vocabulario.

# %%
# Considera la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']

# %%
# Eliminar stopwords
docs_tokens_clean = []
for tokens in docs_tokens:
    filtered_tokens = [word for word in tokens if word not in mis_stopwords]
    docs_tokens_clean.append(filtered_tokens)

# Calcular total de tokens finales
total_tokens_final = sum(len(tokens) for tokens in docs_tokens_clean)
print(f"Total de tokens después de eliminar stopwords: {total_tokens_final}")

# Calcular tokens únicos (vocabulario)
vocabulario = set()
for tokens in docs_tokens_clean:
    vocabulario.update(tokens)

print(f"Total de tokens únicos (vocabulario): {len(vocabulario)}")
# Out:
# Total de tokens después de eliminar stopwords: 5776
# Total de tokens únicos (vocabulario): 1941

# %% [markdown]
# *   **Comentarios**
#
# Incluye finalmente tus comentarios de la actividad.

# %% [markdown]
# Durante esta actividad pude aplicar los conceptos fundamentales del preprocesamiento de texto, como la limpieza de datos, la normalización y la tokenización. Me di cuenta de lo importante que es eliminar caracteres no alfabéticos y unificar el texto en minúsculas para facilitar el análisis posterior. También entendí cómo las stopwords pueden influir en la calidad de los modelos si no se filtran correctamente. Me ayudó a comprender mejor el flujo completo desde tener un corpus "sucio" hasta preparar datos limpios y estructurados listos para utilizarse en tareas de NLP como clasificación o modelado de lenguaje. Además, reforcé mis habilidades usando expresiones regulares en Python para procesar texto de manera eficiente.

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
